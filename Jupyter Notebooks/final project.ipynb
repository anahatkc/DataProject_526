# %% [markdown]
# ## 526 Project brainstorm

# %%
import pandas as pd
import numpy as np
from scipy.special import expit
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib import style ##(double click to add an explanation here)**

# %%
import graphviz as gr

# Create a Directed Graph
g = gr.Digraph()

# Add nodes
g.node('Immigration', label='Immigration')
g.node('PopulationGrowth', label='Population Growth')
g.node('LaborMarket', label='Labor Market')
g.node('IncomeLevels', label='Income Levels')
g.node('DemographicDemand', label='Demographic Demand')
g.node('HousingPrices', label='Housing Prices')
g.node('HousingInventory', label='Housing Inventory')
g.node('EconomicPolicies', label='Economic Policies')
g.node('NationalPolicies', label='National Policies')
g.node('IntegrationOfImmigrants', label='Integration of Immigrants')

# Add edges
g.edge('Immigration', 'PopulationGrowth')
g.edge('PopulationGrowth', 'DemographicDemand')
g.edge('PopulationGrowth', 'LaborMarket')
g.edge('LaborMarket', 'IncomeLevels')
g.edge('LaborMarket', 'DemographicDemand')
g.edge('DemographicDemand', 'HousingPrices')
g.edge('IncomeLevels', 'DemographicDemand')
g.edge('DemographicDemand', 'HousingInventory')
g.edge('EconomicPolicies', 'HousingPrices')
g.edge('NationalPolicies', 'IntegrationOfImmigrants')
g.edge('IntegrationOfImmigrants', 'HousingPrices')

# Render and display the graph
g
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/graphviz/backend/execute.py:79, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      78         kwargs['stdout'] = kwargs['stderr'] = subprocess.PIPE
# ---> 79     proc = _run_input_lines(cmd, input_lines, kwargs=kwargs)
#      80 else:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/graphviz/backend/execute.py:99, in _run_input_lines(cmd, input_lines, kwargs)
#      98 def _run_input_lines(cmd, input_lines, *, kwargs):
# ---> 99     popen = subprocess.Popen(cmd, stdin=subprocess.PIPE, **kwargs)
#     101     stdin_write = popen.stdin.write
#
# ...

# %%
import graphviz as gr

# Create a Directed Graph
g = gr.Digraph()

# Add nodes
g.node('Immigration', label='Immigration')
g.node('PopulationGrowth', label='Population Growth')
g.node('DemographicDemand', label='Demographic Demand')
g.node('EconomicIndicators', label='Economic Indicators')
g.node('HousingDemand', label='Housing Demand')
g.node('SupplyFactors', label='Supply Factors')
g.node('GovernmentPolicies', label='Government Policies')
g.node('HousingMarket', label='Housing Market')

# Add edges
g.edge('Immigration', 'PopulationGrowth')
g.edge('PopulationGrowth', 'DemographicDemand')
g.edge('DemographicDemand', 'HousingDemand')
g.edge('EconomicIndicators', 'HousingDemand')
g.edge('HousingDemand', 'HousingMarket')
g.edge('SupplyFactors', 'HousingMarket')
g.edge('GovernmentPolicies', 'HousingMarket')

# Render and display the graph
g.render(filename='canadian_housing_market_dag', format='png', cleanup=True)
g.view('canadian_housing_market_dag')
# Out:
# 'canadian_housing_market_dag.pdf'

# %%
import graphviz as gr

# Create a Directed Graph
g = gr.Digraph()

# Add nodes
g.node('Immigration', label='Immigration')
g.node('PopulationGrowth', label='Population Growth')
g.node('DemographicDemand', label='Demographic Demand')
g.node('EconomicIndicators', label='Economic Indicators')
g.node('InterestRates', label='Interest Rates')
g.node('EmploymentRates', label='Employment Rates')
g.node('Inflation', label='Inflation')
g.node('MortgageRates', label='Mortgage Rates')
g.node('RegionalFactors', label='Regional Factors')
g.node('HousingDemand', label='Housing Demand')
g.node('SupplyFactors', label='Supply Factors')
g.node('GovernmentPolicies', label='Government Policies')
g.node('HousingMarket', label='Housing Market')

# Add edges
g.edge('Immigration', 'PopulationGrowth')
g.edge('PopulationGrowth', 'DemographicDemand')
g.edge('DemographicDemand', 'HousingDemand')
g.edge('EconomicIndicators', 'HousingDemand')
g.edge('InterestRates', 'HousingDemand')
g.edge('EmploymentRates', 'HousingDemand')
g.edge('Inflation', 'HousingDemand')
g.edge('MortgageRates', 'HousingDemand')
g.edge('RegionalFactors', 'HousingDemand')
g.edge('HousingDemand', 'HousingMarket')
g.edge('SupplyFactors', 'HousingMarket')
g.edge('GovernmentPolicies', 'HousingMarket')

g.render(filename='comprehensive_canadian_housing_market_dag', format='png', cleanup=True)
g.view('comprehensive_canadian_housing_market_dag')

g

# %%
import graphviz as gr

# Create a Directed Graph
g = gr.Digraph()

# Add nodes
g.node('MonetaryPolicy', label='Monetary Policy')
g.node('InterestRates', label='Interest Rates')
g.node('EconomicIndicators', label='Economic Indicators')
g.node('EmploymentRates', label='Employment Rates')
g.node('HousingDemand', label='Housing Demand')
g.node('HousingPrices', label='Housing Prices')

# Add edges
g.edge('MonetaryPolicy', 'InterestRates')
g.edge('MonetaryPolicy', 'EconomicIndicators')
g.edge('EconomicIndicators', 'EmploymentRates')
g.edge('EmploymentRates', 'HousingDemand')
g.edge('InterestRates', 'HousingDemand')
g.edge('HousingDemand', 'HousingPrices')

# Render and display the graph
g

# %%
import graphviz as gr

# Create a Directed Graph
g = gr.Digraph()

# Add nodes
g.node('MonetaryPolicy', label='Monetary Policy')
g.node('InterestRates', label='Interest Rates')
g.node('EconomicIndicators', label='Economic Indicators')
g.node('EmploymentRates', label='Employment Rates')
g.node('HousingDemand', label='Housing Demand')
g.node('HousingPrices', label='Housing Prices')
g.node('HousingSupply', label='Housing Supply')
g.node('ConstructionTrends', label='Construction Trends')
g.node('Regulations', label='Regulations')
g.node('GlobalEconomy', label='Global Economy')

# Add edges
g.edge('MonetaryPolicy', 'InterestRates')
g.edge('MonetaryPolicy', 'EconomicIndicators')
g.edge('EconomicIndicators', 'EmploymentRates')
g.edge('EmploymentRates', 'HousingDemand')
g.edge('InterestRates', 'HousingDemand')
g.edge('HousingDemand', 'HousingPrices')
g.edge('HousingSupply', 'HousingPrices')
g.edge('ConstructionTrends', 'HousingSupply')
g.edge('Regulations', 'HousingSupply')
g.edge('GlobalEconomy', 'HousingPrices')
g.edge('GlobalEconomy', 'HousingSupply')

# Render and display the graph

g

# %%
import graphviz as gr

# Create a Directed Graph
g = gr.Digraph()

# Add edges
g.edge('Age', 'DemographicDemand')
g.edge('PopulationGrowth', 'DemographicDemand')
g.edge('DemographicDemand', 'HousingDemand')
g.edge('EconomicIndicators', 'HousingDemand')
g.edge('InterestRates', 'HousingDemand')
g.edge('EmploymentRates', 'HousingDemand')
g.edge('Inflation', 'HousingDemand')
g.edge('MortgageRates', 'HousingDemand')
g.edge('RegionalFactors', 'HousingDemand')



g

# %%
import graphviz as gr

# Create a Directed Graph
g = gr.Digraph()

# Add edges
g.edge('Age', 'DemographicDemand')
g.edge('PopulationGrowth', 'DemographicDemand')
g.edge('DemographicDemand', 'HousingDemand')
g.edge('EconomicIndicators', 'HousingDemand')
g.edge('InterestRates', 'HousingDemand')
g.edge('EmploymentRates', 'HousingDemand')
g.edge('Inflation', 'HousingDemand')
g.edge('MortgageRates', 'HousingDemand')
g.edge('RegionalFactors', 'HousingDemand')

# Additional nodes and edges
g.edge('Education', 'EmploymentRates')
g.edge('IncomeLevels', 'EconomicIndicators')
g.edge('ConsumerConfidence', 'EconomicIndicators')
g.edge('GovernmentPolicy', 'EconomicIndicators')
g.edge('MarketSentiment', 'HousingDemand')
g.edge('RealEstateInvestment', 'HousingDemand')
g.edge('Urbanization', 'RegionalFactors')
g.edge('InfrastructureDevelopment', 'RegionalFactors')
g.edge('Climate', 'RegionalFactors')

# Links going both ways
g.edge('EconomicIndicators', 'InterestRates', constraint='false')
g.edge('EconomicIndicators', 'Inflation', constraint='false')
g.edge('EconomicIndicators', 'MortgageRates', constraint='false')
g.edge('HousingDemand', 'RealEstateInvestment', constraint='false')

g

# %%
import graphviz as gr

# Create a Directed Graph
g = gr.Digraph()

# Add edges
g.edge('Age', 'DemographicDemand')
g.edge('PopulationGrowth', 'DemographicDemand')
g.edge('DemographicDemand', 'HousingDemand')
g.edge('EconomicIndicators', 'HousingDemand')
g.edge('InterestRates', 'HousingDemand')
g.edge('EmploymentRates', 'HousingDemand')
g.edge('Inflation', 'HousingDemand')
g.edge('MortgageRates', 'HousingDemand')
g.edge('RegionalFactors', 'HousingDemand')

# Additional nodes and edges
g.edge('Education', 'EmploymentRates')
g.edge('IncomeLevels', 'EconomicIndicators')
g.edge('ConsumerConfidence', 'EconomicIndicators')
g.edge('GovernmentPolicy', 'EconomicIndicators')
g.edge('MarketSentiment', 'HousingDemand')
g.edge('RealEstateInvestment', 'HousingDemand')
g.edge('Urbanization', 'RegionalFactors')
g.edge('InfrastructureDevelopment', 'RegionalFactors')
g.edge('Climate', 'RegionalFactors')

# Links going both ways
g.edge('EconomicIndicators', 'InterestRates', constraint='false')
g.edge('EconomicIndicators', 'Inflation', constraint='false')
g.edge('EconomicIndicators', 'MortgageRates', constraint='false')
g.edge('HousingDemand', 'RealEstateInvestment', constraint='false')

# Additional links
g.edge('DemographicDemand', 'Urbanization', constraint='false')
g.edge('DemographicDemand', 'ConsumerConfidence', constraint='false')
g.edge('EmploymentRates', 'IncomeLevels', constraint='false')
g.edge('RegionalFactors', 'InfrastructureDevelopment', constraint='false')
g.edge('RegionalFactors', 'Climate', constraint='false')

g

# %% [markdown]
# ## SVAR Code

# %%
import statsmodels.api as sm

# Assuming df is a DataFrame containing your time-series data
model = sm.tsa.VAR(df)
results = model.fit(maxlags=2)  # Adjust the lag order as needed

irf = results.irf(10)  # Adjust the number of periods as needed
irf.plot(orth=True)


var_decomp = results.fevd(10)  # Adjust the number of periods as needed
var_decomp.plot()

# %%
import graphviz as gr

# Create a Directed Graph
g = gr.Digraph()

# Add edges based on the relationships in your context
g.edge('MonetaryPolicyShock', 'OutputGrowth')
g.edge('MonetaryPolicyShock', 'Consumption')
g.edge('MonetaryPolicyShock', 'HousingSupply')
g.edge('MonetaryPolicyShock', 'HousePrices')
g.edge('FinancialMarketShock', 'BankLending')
g.edge('FinancialMarketShock', 'StockMarket')
g.edge('OverallEconomy', 'Consumption')
g.edge('OverallEconomy', 'OutputGrowth')
g.edge('OverallEconomy', 'ExchangeRate')
g.edge('HousingSupply', 'HousePrices')
g.edge('BankLending', 'HousePrices')
g.edge('StockMarket', 'HousePrices')

g

# %%
import graphviz as gr

# Create a Directed Graph
g = gr.Digraph()

#g.edge(['MonetaryPolicyShock', 'OutputGrowth', 'Consumption', 'HousingSupply', 'HousePrices', 'BankLending', 'StockMarket', 'OverallEconomy'])
g.edge('MonetaryPolicyShock', 'InterestRate')
g.edge('MonetaryPolicyShock', 'CreditSupply')
g.edge('MonetaryPolicyShock', 'Wealth')
g.edge('MonetaryPolicyShock', 'MacroeconomicTools')
g.edge('CreditSupply', 'BankLending')
g.edge('BankLending', 'Consumption')
g.edge('BankLending', 'HousingSupply')
g.edge('Wealth', 'Consumption')
g.edge('Wealth', 'HousePrices')
g.edge('InterestRate', 'Consumption')
g.edge('InterestRate', 'AdjustableInterestRate')
g.edge('AdjustableInterestRate', 'Consumption')
g.edge('HousingSupply', 'HousePrices')
g.edge('HousePrices', 'Wealth')
g.edge('ConstructionGap', 'HousePrices')
g.edge('PopulationGrowth', 'ConstructionGap')
g.edge('MacroeconomicTools', 'AdjustableInterestRate')

g

# %% [markdown]
# ## Heading here
